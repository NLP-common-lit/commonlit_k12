# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import KFold
import requests
import re
import warnings
warnings.filterwarnings("ignore")

import unicodedata
import nltk
from nltk.tokenize.toktok import ToktokTokenizer
from nltk.corpus import stopwords

from prepare import missing_values_table

# %%
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#           id url_legal license  \
# 0  c12129c31       NaN     NaN
# 1  85aa80a4c       NaN     NaN
# 2  b69ac6792       NaN     NaN
# 3  dd1000b26       NaN     NaN
# 4  37c1b32fb       NaN     NaN
#
#                                                                                      excerpt  \
# 0  When the young people returned to the ballroom, it presented a decidedly changed appea...
# 1  All through dinner time, Mrs. Fayre was somewhat silent, her eyes resting on Dolly wit...
# 2  As Roger had predicted, the snow departed as quickly as it came, and two days after th...
# 3  And outside before the palace a great garden was walled round, filled full of stately ...
# 4  Once upon a time there were Three Bears who lived together in a house of their own in ...
#
#      target  standard_error
# 0 -0.340259        0.464009
# 1 -0.315372        0.480805
# 2 -0.580118        0.476676
# 3 -1.054013        0.450007
# 4  0.247197        0.510845

# %%
df.shape
# Out:
# (2834, 6)

# %%
df.drop_duplicates()
# Out:
#              id  \
# 0     c12129c31
# 1     85aa80a4c
# 2     b69ac6792
# 3     dd1000b26
# 4     37c1b32fb
# ...         ...
# 2829  25ca8f498
# 2830  2c26db523
# 2831  cd19e2350
# 2832  15e2e9e7a
# 2833  5b990ba77
#
#                                                                          url_legal  \
# 0                                                                              NaN
# 1                                                                              NaN
# 2                                                                              NaN
# 3                                                                              NaN
# 4                                                                              NaN
# ...                                                                            ...
# 2829  https://sites.ehe.osu.edu/beyondpenguins/files/2011/06/dinosaurs_45_text.pdf
# 2830                  https://en.wikibooks.org/wiki/Wikijunior:The_Elements/Solids
# 2831                 https://en.wikibooks.org/wiki/Wikijunior:The_Elements/Liquids
# 2832           https://en.wikibooks.org/wiki/Geometry_for_Elementary_School/Solids
# 2833             https://en.wikibooks.org/wiki/Wikijunior:Biology/Kingdoms/Animals
#
#            license  \
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 2829  CC BY-SA 3.0
# 2830  CC BY-SA 3.0
# 2831  CC BY-SA 3.0
# 2832  CC BY-SA 3.0
# 2833  CC BY-SA 3.0
#
#                                                                                         excerpt  \
# 0     When the young people returned to the ballroom, it presented a decidedly changed appea...
# 1     All through dinner time, Mrs. Fayre was somewhat silent, her eyes resting on Dolly wit...
# 2     As Roger had predicted, the snow departed as quickly as it came, and two days after th...
# 3     And outside before the palace a great garden was walled round, filled full of stately ...
# 4     Once upon a time there were Three Bears who lived together in a house of their own in ...
# ...                                                                                         ...
# 2829  When you think of dinosaurs and where they lived, what do you picture? Do you see hot,...
# 2830  So what is a solid? Solids are usually hard because their molecules have been packed t...
# 2831  The second state of matter we will discuss is a liquid. Solids are hard things you can...
# 2832  Solids are shapes that you can actually touch. They have three dimensions, which means...
# 2833  Animals are made of many cells. They eat things and digest them inside. Most animals c...
#
#         target  standard_error
# 0    -0.340259        0.464009
# 1    -0.315372        0.480805
# 2    -0.580118        0.476676
# 3    -1.054013        0.450007
# 4     0.247197        0.510845
# ...        ...             ...
# 2829  1.711390        0.646900
# 2830  0.189476        0.535648
# 2831  0.255209        0.483866
# 2832 -0.215279        0.514128
# 2833  0.300779        0.512379
#
# [2834 rows x 6 columns]

# %%
# Set id as index
df.set_index('id', inplace = True)

# %%
# no duplicates found
# check for NaNs

missing_values_table(df)
# Out:
# Your selected dataframe has 5 columns and 2834 Rows.
# There are 2 columns that have NULL values.
#                 Zero Values  null_count  % of Total Values  \
# url_legal                 0        2004               70.7
# license                   0        2004               70.7
# excerpt                   0           0                0.0
# target                    1           0                0.0
# standard_error            1           0                0.0
#
#                 Total Zeroes + Null Values  % Total Zero + Null Values  \
# url_legal                             2004                        70.7
# license                               2004                        70.7
# excerpt                                  0                         0.0
# target                                   1                         0.0
# standard_error                           1                         0.0
#
#                Data Type
# url_legal         object
# license           object
# excerpt           object
# target           float64
# standard_error   float64

# %% [markdown]
# over 2000 nulls are present in the url_legal and in the license...let's drop these

# %%
df.drop(columns=['url_legal', 'license'], inplace=True)

# %%
df.head()
# Out:
#                                                                                              excerpt  \
# id
# c12129c31  When the young people returned to the ballroom, it presented a decidedly changed appea...
# 85aa80a4c  All through dinner time, Mrs. Fayre was somewhat silent, her eyes resting on Dolly wit...
# b69ac6792  As Roger had predicted, the snow departed as quickly as it came, and two days after th...
# dd1000b26  And outside before the palace a great garden was walled round, filled full of stately ...
# 37c1b32fb  Once upon a time there were Three Bears who lived together in a house of their own in ...
#
#              target  standard_error
# id
# c12129c31 -0.340259        0.464009
# 85aa80a4c -0.315372        0.480805
# b69ac6792 -0.580118        0.476676
# dd1000b26 -1.054013        0.450007
# 37c1b32fb  0.247197        0.510845

# %%
#find narratives with nulls
null_narrative = df[df['excerpt'].isnull()].index

# %%
#Clean up quotes

def clean_nlp(df):
    
    'A simple function to cleanup text data'
    
    ADDITIONAL_STOPWORDS = ['r', 'u', '2', 'ltgt', '\n', 'ha', 'n', '41']
    
    wnl = nltk.stem.WordNetLemmatizer()
    stopwords = nltk.corpus.stopwords.words('english')+ ADDITIONAL_STOPWORDS
    narrative = (unicodedata.normalize('NFKD', narrative)
             .encode('ascii', 'ignore')
             .decode('utf-8', 'ignore')
             .lower())
    words = re.sub(r'[^\w\s]', '', narrative).split()
    return [wnl.lemmatize(word) for word in words if word not in stopwords]
